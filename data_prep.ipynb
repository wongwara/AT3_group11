# %% [markdown]
# # Data preperation - create whole dataset
#
# Check with the answer in discussion board: https://canvas.uts.edu.au/courses/26202/discussion_topics/378285

# %%
import os
import pandas as pd

# %%
# cwd = os.getcwd()  # Get the current working directory (cwd)
# files = os.listdir(cwd)  # Get all the files in that directory
# print("Files in %r: %s" % (cwd, files))

# %%
customer= pd.read_csv('/Users/lilywijara/Desktop/final/customers.csv', sep='|')

# %%
customer.shape
# Out:
# (1000, 15)

# %%
customer.head()
# Out:
#            ssn               cc_num     first       last gender  \
# 0  115-04-4507        4218196001337  Jonathan    Johnson      M
# 1  715-55-5575  4351161559407816183    Elaine     Fuller      F
# 2  167-48-5821        4192832764832   Michael    Cameron      M
# 3  406-83-7518     4238849696532874   Brandon   Williams      M
# 4  697-93-1877     4514627048281480      Lisa  Hernandez      F
#
#                        street        city state    zip      lat     long  \
# 0        863 Lawrence Valleys      Ambler    PA  19002  40.1809 -75.2156
# 1  310 Kendra Common Apt. 164      Leland    NC  28451  34.2680 -78.0578
# 2            05641 Robin Port     Cordova    SC  29039  33.4275 -80.8857
# 3      26916 Carlson Mountain  Birmingham    AL  35242  33.3813 -86.7046
# 4             809 Burns Creek       Fargo    GA  31631  30.7166 -82.5801
#
#    city_pop                                    job         dob      acct_num
# ...

# %% [markdown]
# The number of customers is 1000.

# %%
# read the path
file_path = '/Users/lilywijara/Desktop/final'

#list all the files from the path
file_list = os.listdir(file_path)

# %%
file_list
# Out:
# ['transactions_12.csv',
#  'transactions_126.csv',
#  'transactions_127.csv',
#  'transactions_13.csv',
#  'customers.csv',
#  'transactions_39.csv',
#  'transactions_11.csv',
#  'transactions_119.csv',
#  'transactions_131.csv',
#  'transactions_125.csv',
#  'transactions_124.csv',
#  'transactions_130.csv',
#  'transactions_118.csv',
#  'transactions_10.csv',
#  'transactions_38.csv',
#  'transactions_14.csv',
#  'transactions_28.csv',
#  'transactions_120.csv',
#  'transactions_108.csv',
#  '.DS_Store',
#  'transactions_109.csv',
#  'transactions_121.csv',
#  'transactions_29.csv',
#  'transactions_15.csv',
#  'transactions_17.csv',
#  'transactions_123.csv',
#  'transactions_122.csv',
#  'transactions_16.csv',
#  'transactions_59.csv',
#  'transactions_65.csv',
#  'transactions_71.csv',
#  'transactions_7.csv',
#  'transactions_6.csv',
#  'transactions_70.csv',
#  'transactions_64.csv',
#  'transactions_58.csv',
#  'transactions_72.csv',
#  'transactions_4.csv',
# ...

# %% [markdown]
# ## Merge 2 file

# %%
transactions_1 = pd.read_csv('/Users/lilywijara/Desktop/final/transactions_1.csv', sep='|')
transactions_2 = pd.read_csv('/Users/lilywijara/Desktop/final/transactions_2.csv', sep='|')

# %%
transactions_master = transactions_1.merge(transactions_2, 
                   how = 'outer')
transactions_master
# Out:
#                  cc_num      acct_num                         trans_num  \
# 0      4065133387262473  950105810049  8bc87b4a938a94de66c73312a70b955e
# 1      4065133387262473  950105810049  a091d0441f62b8195a005b698a9b25d7
# 2      4065133387262473  950105810049  e458e6934892d3871fc49483f6744eab
# 3      4065133387262473  950105810049  ec9286554b98b0f6272e7ad3e79ac46a
# 4      4065133387262473  950105810049  ff9109f3fcfc870213143c7cd55dee1c
# ...                 ...           ...                               ...
# 69212  4646726368154185   44386431879  66fe860ddf8077e7bcc7d60606893c92
# 69213  4646726368154185   44386431879  319088b8fc37909de223cd7beb6177c2
# 69214  4646726368154185   44386431879  c70810355ef6878b86c34dbb6f8efbae
# 69215  4646726368154185   44386431879  7cfcf2b4d3453c594612e825a823ad72
# 69216  4646726368154185   44386431879  c2b1d6abaf4e734e7c6484311d936d82
#
#         unix_time        category    amt  is_fraud  \
# ...

# %% [markdown]
# ## For loop to merge 132 files

# %%
import pandas as pd

# create an empty list to store the transaction dataframes
transactions_list = []

# loop through the file names.
for i in range(0, 131):
    file_name = f'/Users/lilywijara/Desktop/final/transactions_{i}.csv'
    try:
        # read in the transaction data for each file and append it to the list
        transactions_list.append(pd.read_csv(file_name, sep='|'))
    except FileNotFoundError:
        # if the file is not found, print an error message and continue to the next file
        print(f"File {file_name} not found, skipping...")

# merge all the transaction dataframes into a single master transactions dataset
transactions_master = pd.concat(transactions_list, axis=0, ignore_index=True)

# print the merged dataset
transactions_master
# Out:
#                    cc_num      acct_num                         trans_num  \
# 0           4218196001337  888022315787  91ab12e73ef38206e1121e9648d2408d
# 1           4218196001337  888022315787  071553d533a6822a4431c354c434ddcb
# 2           4218196001337  888022315787  0cfad38ef15e4749eff68dc83f62c151
# 3           4218196001337  888022315787  5782693d7c70f062f258cb30bfa8900f
# 4           4218196001337  888022315787  35fd7db657d7e30dd608c37f7798186e
# ...                   ...           ...                               ...
# 4260899  2704390552958068  756767582811  1f091e64bd3f2382b3a4f90889329c32
# 4260900  2704390552958068  756767582811  971aa63530f8f8fb1de28472e6aa53bc
# 4260901  2704390552958068  756767582811  555941e364d1f591a6ae4088557f8ed3
# 4260902  2704390552958068  756767582811  b756330bb5da439e28412f40e7a5f9e3
# 4260903  2704390552958068  756767582811  d8b2caf59c06c36fea6980964f0a1fd6
#
#           unix_time        category    amt is_fraud  \
# ...

# %% [markdown]
# The total number of transactions are 4,260,904.

# %% [markdown]
# ## Merge the customer file with transactions

# %%
# merge the two datasets on the 'cc_num' and 'acct_num' columns
df = pd.merge(transactions_master, customer, on=['cc_num', 'acct_num'], how='left')

# print the merged dataset
print(df)
# Out:
#                    cc_num      acct_num                         trans_num  \
# 0           4218196001337  888022315787  91ab12e73ef38206e1121e9648d2408d
# 1           4218196001337  888022315787  071553d533a6822a4431c354c434ddcb
# 2           4218196001337  888022315787  0cfad38ef15e4749eff68dc83f62c151
# 3           4218196001337  888022315787  5782693d7c70f062f258cb30bfa8900f
# 4           4218196001337  888022315787  35fd7db657d7e30dd608c37f7798186e
# ...                   ...           ...                               ...
# 4260899  2704390552958068  756767582811  1f091e64bd3f2382b3a4f90889329c32
# 4260900  2704390552958068  756767582811  971aa63530f8f8fb1de28472e6aa53bc
# 4260901  2704390552958068  756767582811  555941e364d1f591a6ae4088557f8ed3
# 4260902  2704390552958068  756767582811  b756330bb5da439e28412f40e7a5f9e3
# 4260903  2704390552958068  756767582811  d8b2caf59c06c36fea6980964f0a1fd6
#
#           unix_time        category    amt is_fraud  \
# ...

# %% [markdown]
# ## Check the final dataset

# %%
df.shape
# Out:
# (4260904, 23)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4260904 entries, 0 to 4260903
# Data columns (total 23 columns):
#  #   Column      Dtype
# ---  ------      -----
#  0   cc_num      object
#  1   acct_num    object
#  2   trans_num   object
#  3   unix_time   object
#  4   category    object
#  5   amt         float64
#  6   is_fraud    object
#  7   merchant    object
#  8   merch_lat   float64
#  9   merch_long  float64
#  10  ssn         object
#  11  first       object
#  12  last        object
#  13  gender      object
#  14  street      object
#  15  city        object
#  16  state       object
#  17  zip         int64
#  18  lat         float64
#  19  long        float64
#  20  city_pop    int64
#  21  job         object
#  22  dob         object
# dtypes: float64(5), int64(2), object(16)
# memory usage: 780.2+ MB

# %%
df.head()
# Out:
#           cc_num      acct_num                         trans_num   unix_time  \
# 0  4218196001337  888022315787  91ab12e73ef38206e1121e9648d2408d  1558719550
# 1  4218196001337  888022315787  071553d533a6822a4431c354c434ddcb  1569425519
# 2  4218196001337  888022315787  0cfad38ef15e4749eff68dc83f62c151  1577205601
# 3  4218196001337  888022315787  5782693d7c70f062f258cb30bfa8900f  1571428238
# 4  4218196001337  888022315787  35fd7db657d7e30dd608c37f7798186e  1549840400
#
#         category    amt is_fraud        merchant  merch_lat  merch_long  ...  \
# 0  gas_transport  69.12        0  Phillips Group  39.491416  -75.588522  ...
# 1    grocery_pos  68.11        0      Tucker Ltd  40.890319  -75.573359  ...
# 2       misc_net  40.35        0       Dixon PLC  39.244958  -74.475327  ...
# 3    grocery_pos  96.22        0  Lambert-Cooper  39.656925  -75.802342  ...
# 4  gas_transport  71.89        0    Griffith LLC  40.313342  -74.220434  ...
#
# ...

# %% [markdown]
# ## Save into df.csv

# %%
# df.to_csv('df.csv')

# %% [markdown]
# ## Reference:
#
# Joshua, S. (2022, April 25). How to combine multiple CSV files using Python for your analysis. Medium. https://medium.com/@stella96joshua/how-to-combine-multiple-csv-files-using-python-for-your-analysis-a88017c6ff9e
#
# Opallage, M. (2020, September 8). Answer to ‘python pandas error tokenizing data’. Stack Overflow. https://stackoverflow.com/a/63797557

# %% [markdown]
# ***
# **Subject**: 36106 Machine Learning Algorithms and Applications - Autumn 2023
#
# **University**: University of Technology Sydney
# ***
